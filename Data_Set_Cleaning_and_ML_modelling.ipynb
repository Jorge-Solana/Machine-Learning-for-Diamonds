# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import mean_squared_error

from sklearn.metrics import fbeta_score

# %% [markdown]
# ## Let's explore the dataset!

# %%
d_train = pd.read_csv('./train.csv')

# %%
d_test = pd.read_csv('./test.csv')

# %%
d_train.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1   1   1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# 2   2   0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54  7.983
# 3   3   1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12  8.371
# 4   4   0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82  6.588

# %%
d_train.shape
# Out:
# (40455, 11)

# %%
d_train.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
# not nulls yuhuuu

# %%
d_train.dtypes
# Out:
# id           int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price      float64
# dtype: object

# %% [markdown]
# ## Let's see what can we do with the categorical columns

# %% [markdown]
# I am going to assume that all the 3 categorical variables are important in a certain order.
#
# This is obvious in the cut (Ideal is the best, therefore a 5 out of 5). With the color, at first I am going to assume the same, the are colors which have more market value than others. The clarity works the same as color.

# %% [markdown]
# ####  - Cut

# %%
d_train.cut.value_counts()
# Out:
# Ideal        16230
# Premium      10338
# Very Good     9003
# Good          3682
# Fair          1202
# Name: cut, dtype: int64

# %%
category = {
    'Ideal' : 5,
    'Premium' : 4,
    'Very Good' : 3,
    'Good' : 2,
    'Fair' : 1   
}

# %%
d_train.cut = d_train.cut.map(category)

# %%
d_train.sample()
# Out:
#           id  carat  cut color clarity  depth  table     x     y     z  price
# 38473  38473    0.4    5     E     VS1   61.2   55.0  4.76  4.79  2.92  6.846

# %%
sns.countplot(data=d_train, x=d_train.cut);

# %% [markdown]
# #### - Color

# %%
d_train.color.value_counts()
# Out:
# G    8410
# E    7368
# F    7182
# H    6203
# D    5100
# I    4070
# J    2122
# Name: color, dtype: int64

# %%
color_ = {
    'G' : 1,
    'E': 2,
    'F': 3,
    'H': 4,
    'D': 5,
    'I': 6,
    'J': 7
}

# %%
d_train.color = d_train.color.map(color_)

# %%
d_train.sample()
# Out:
#         id  carat  cut  color clarity  depth  table     x     y     z  price
# 1923  1923   0.71    2      4     VS1   63.6   55.0  5.58  5.65  3.57  7.747

# %%
sns.countplot(data=d_train, x=d_train.color);

# %% [markdown]
# #### - Clarity

# %%
d_train.clarity.value_counts()
# Out:
# SI1     9779
# VS2     9259
# SI2     6921
# VS1     6079
# VVS2    3745
# VVS1    2807
# IF      1312
# I1       553
# Name: clarity, dtype: int64

# %%
calrity_ = {
    'SI2': 1, 
    'VVS2': 2, 
    'VS2': 3, 
    'VS1': 4, 
    'SI1': 5, 
    'VVS1': 6, 
    'IF': 7, 
    'I1': 8
}

# %%
d_train.clarity = d_train.clarity.map(calrity_)

# %%
d_train.sample()
# Out:
#           id  carat      cut color  clarity  depth  table    x     y     z  \
# 12821  12821   0.39  Premium     G        3   60.4   61.0  4.7  4.67  2.83
#
#        price
# 12821  6.917

# %%
# DONE

# %% [markdown]
# ## Now let's see which are the 4c´s of a Diamond

# %% [markdown]
# This are, in  order of most valuable to least:
#
# - Carat
#
# - Color
#
# - Clarity
#
# - Cut

# %% [markdown]
# This are the most important features of a diamond, but we can not ignore other features as table, depth (z)...

# %%
correlation = d_train.corr()

# %%
correlation
# Out:
#                id     carat   clarity     depth     table         x         y  \
# id       1.000000 -0.003045  0.001354 -0.000405  0.000783 -0.002447 -0.001936
# carat   -0.003045  1.000000 -0.155426  0.023585  0.185478  0.974648  0.944419
# clarity  0.001354 -0.155426  1.000000  0.022249 -0.061169 -0.163722 -0.159106
# depth   -0.000405  0.023585  0.022249  1.000000 -0.299203 -0.029867 -0.033960
# table    0.000783  0.185478 -0.061169 -0.299203  1.000000  0.200374  0.186788
# x       -0.002447  0.974648 -0.163722 -0.029867  0.200374  1.000000  0.967315
# y       -0.001936  0.944419 -0.159106 -0.033960  0.186788  0.967315  1.000000
# z       -0.001273  0.947469 -0.155915  0.089474  0.153726  0.965496  0.941176
# price   -0.003194  0.920064 -0.122930 -0.003292  0.162804  0.957668  0.928909
#
#                 z     price
# id      -0.001273 -0.003194
# carat    0.947469  0.920064
# clarity -0.155915 -0.122930
# depth    0.089474 -0.003292
# table    0.153726  0.162804
# x        0.965496  0.957668
# y        0.941176  0.928909
# z        1.000000  0.930014
# price    0.930014  1.000000

# %%
sns.heatmap(correlation);

# %% [markdown]
# ## Machine Learning time!

# %%
# lets start with a decision tree

# %%
X = d_train.drop("price", axis=1)
y = d_train.price

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666)

# %%
model_tree_13 = DecisionTreeRegressor(max_depth=13)

# %%
model_tree_13.fit(X_train, y_train)

# %%
y_predict = model_tree_13.predict(X_test).round(3)

# %%
y_predict

# %%
RMSE = (mean_squared_error(y_test, y_predict)) ** 0.5

# %%
RMSE
# Out:
# 0.12346616022338473

# %%
d_test.head()
# Out:
#    id  carat      cut color clarity  depth  table     x     y     z
# 0   0   0.32    Ideal     I     SI1   60.5   58.0  4.43  4.49  2.70
# 1   1   1.24  Premium     I     SI1   62.9   60.0  6.80  6.74  4.26
# 2   2   1.66  Premium     D     SI1   62.0   59.0  7.55  7.60  4.70
# 3   3   0.75  Premium     D     SI2   60.6   56.0  5.94  5.90  3.59
# 4   4   1.50     Fair     E     SI2   64.8   55.0  7.26  7.15  4.67

# %%
d_test.cut = d_test.cut.map(category)
d_test.color = d_test.color.map(color_)
d_test.clarity = d_test.clarity.map(calrity_)

# %%
d_test.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z
# 0   0   0.32    5      6        5   60.5   58.0  4.43  4.49  2.70
# 1   1   1.24    4      6        5   62.9   60.0  6.80  6.74  4.26
# 2   2   1.66    4      5        5   62.0   59.0  7.55  7.60  4.70
# 3   3   0.75    4      5        1   60.6   56.0  5.94  5.90  3.59
# 4   4   1.50    1      2        1   64.8   55.0  7.26  7.15  4.67

# %%
y_predict_1 = model_tree_13.predict(d_test).round(3)

# %%
y_predict_1
# Out:
# array([6.037, 8.354, 9.524, ..., 6.508, 8.842, 7.908])

# %%
d_test['price'] = y_predict_1

# %%
d_test.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   0.32    5      6        5   60.5   58.0  4.43  4.49  2.70  6.037
# 1   1   1.24    4      6        5   62.9   60.0  6.80  6.74  4.26  8.354
# 2   2   1.66    4      5        5   62.0   59.0  7.55  7.60  4.70  9.524
# 3   3   0.75    4      5        1   60.6   56.0  5.94  5.90  3.59  7.925
# 4   4   1.50    1      2        1   64.8   55.0  7.26  7.15  4.67  8.968

# %%
d_up = d_test.drop(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis = 1)

# %%
d_up.head()
# Out:
#    id  price
# 0   0  6.037
# 1   1  8.354
# 2   2  9.524
# 3   3  7.925
# 4   4  8.968

# %%
d_up.to_csv('upload1.csv', index=False)

# %%
# lets do a for loop for obtaining different models and printing them

# %%
results = []

for depth in range(1, 21):
    model = DecisionTreeRegressor(max_depth=depth, random_state=666)
    model.fit(X_train, y_train)
    
    result = {
        "model": model,
        "depth": depth,
        "train_RMSE": (mean_squared_error(y_train, model.predict(X_train))) ** 0.5,
        "test_RMSE": (mean_squared_error(y_test, model.predict(X_test))) ** 0.5
    }
    
    results.append(result)

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                                                 model  depth  train_RMSE  \
# 0   DecisionTreeRegressor(max_depth=1, random_stat...      1    0.533089
# 1   DecisionTreeRegressor(max_depth=2, random_stat...      2    0.353706
# 2   DecisionTreeRegressor(max_depth=3, random_stat...      3    0.273429
# 3   DecisionTreeRegressor(max_depth=4, random_stat...      4    0.245985
# 4   DecisionTreeRegressor(max_depth=5, random_stat...      5    0.221688
# 5   DecisionTreeRegressor(max_depth=6, random_stat...      6    0.200375
# 6   DecisionTreeRegressor(max_depth=7, random_stat...      7    0.180191
# 7   DecisionTreeRegressor(max_depth=8, random_stat...      8    0.158507
# 8   DecisionTreeRegressor(max_depth=9, random_stat...      9    0.141227
# 9   DecisionTreeRegressor(max_depth=10, random_sta...     10    0.125229
# 10  DecisionTreeRegressor(max_depth=11, random_sta...     11    0.112939
# 11  DecisionTreeRegressor(max_depth=12, random_sta...     12    0.101347
# 12  DecisionTreeRegressor(max_depth=13, random_sta...     13    0.090132
# 13  DecisionTreeRegressor(max_depth=14, random_sta...     14    0.079524
# 14  DecisionTreeRegressor(max_depth=15, random_sta...     15    0.068603
# 15  DecisionTreeRegressor(max_depth=16, random_sta...     16    0.058817
# 16  DecisionTreeRegressor(max_depth=17, random_sta...     17    0.049258
# 17  DecisionTreeRegressor(max_depth=18, random_sta...     18    0.040843
# 18  DecisionTreeRegressor(max_depth=19, random_sta...     19    0.033352
# 19  DecisionTreeRegressor(max_depth=20, random_sta...     20    0.027005
#
#     test_RMSE
# 0    0.535040
# 1    0.349787
# 2    0.269817
# 3    0.246475
# 4    0.225897
# 5    0.202485
# 6    0.184130
# 7    0.162920
# 8    0.149220
# 9    0.137059
# 10   0.130654
# 11   0.127193
# 12   0.123930
# 13   0.120707
# 14   0.121113
# 15   0.122755
# 16   0.123281
# 17   0.124416
# 18   0.124629
# 19   0.130120

# %%
# lets plot all of them to check where it starts to fall appart (our model)

# %%
fig = plt.figure(figsize=(10, 10))
plt.plot(results_df.depth, results_df.train_RMSE, label="train RMSE")
plt.plot(results_df.depth, results_df.test_RMSE, label="test RMSE")
plt.legend();

# %%
gs = GridSearchCV(
    estimator=DecisionTreeRegressor(),
    param_grid={
        "max_depth": [10, 11, 12, 13, 14],
        "min_samples_split": [30, 50, 100, 120],
    },
    cv=5,
    verbose=3,
    scoring="neg_mean_squared_error",
    return_train_score=True
)

# %%
# %%time
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .............max_depth=10, min_samples_split=30; total time=   0.3s
# [CV 2/5] END .............max_depth=10, min_samples_split=30; total time=   0.3s
# [CV 3/5] END .............max_depth=10, min_samples_split=30; total time=   0.3s
# [CV 4/5] END .............max_depth=10, min_samples_split=30; total time=   0.3s
# [CV 5/5] END .............max_depth=10, min_samples_split=30; total time=   0.3s
# [CV 1/5] END .............max_depth=10, min_samples_split=50; total time=   0.3s
# [CV 2/5] END .............max_depth=10, min_samples_split=50; total time=   0.3s
# [CV 3/5] END .............max_depth=10, min_samples_split=50; total time=   0.3s
# [CV 4/5] END .............max_depth=10, min_samples_split=50; total time=   0.3s
# [CV 5/5] END .............max_depth=10, min_samples_split=50; total time=   0.3s
# [CV 1/5] END ............max_depth=10, min_samples_split=100; total time=   0.3s
# [CV 2/5] END ............max_depth=10, min_samples_split=100; total time=   0.3s
# [CV 3/5] END ............max_depth=10, min_samples_split=100; total time=   0.3s
# [CV 4/5] END ............max_depth=10, min_samples_split=100; total time=   0.3s
# [CV 5/5] END ............max_depth=10, min_samples_split=100; total time=   0.3s
# [CV 1/5] END ............max_depth=10, min_samples_split=120; total time=   0.3s
# [CV 2/5] END ............max_depth=10, min_samples_split=120; total time=   0.3s
# [CV 3/5] END ............max_depth=10, min_samples_split=120; total time=   0.3s
# [CV 4/5] END ............max_depth=10, min_samples_split=120; total time=   0.3s
# [CV 5/5] END ............max_depth=10, min_samples_split=120; total time=   0.3s
# [CV 1/5] END .............max_depth=11, min_samples_split=30; total time=   0.3s
# [CV 2/5] END .............max_depth=11, min_samples_split=30; total time=   0.3s
# [CV 3/5] END .............max_depth=11, min_samples_split=30; total time=   0.3s
# [CV 4/5] END .............max_depth=11, min_samples_split=30; total time=   0.3s
# [CV 5/5] END .............max_depth=11, min_samples_split=30; total time=   0.4s
# [CV 1/5] END .............max_depth=11, min_samples_split=50; total time=   0.3s
# [CV 2/5] END .............max_depth=11, min_samples_split=50; total time=   0.3s
# [CV 3/5] END .............max_depth=11, min_samples_split=50; total time=   0.3s
# [CV 4/5] END .............max_depth=11, min_samples_split=50; total time=   0.3s
# [CV 5/5] END .............max_depth=11, min_samples_split=50; total time=   0.3s
# [CV 1/5] END ............max_depth=11, min_samples_split=100; total time=   0.3s
# [CV 2/5] END ............max_depth=11, min_samples_split=100; total time=   0.3s
# [CV 3/5] END ............max_depth=11, min_samples_split=100; total time=   0.3s
# [CV 4/5] END ............max_depth=11, min_samples_split=100; total time=   0.2s
# [CV 5/5] END ............max_depth=11, min_samples_split=100; total time=   0.3s
# [CV 1/5] END ............max_depth=11, min_samples_split=120; total time=   0.3s
# [CV 2/5] END ............max_depth=11, min_samples_split=120; total time=   0.3s
# [CV 3/5] END ............max_depth=11, min_samples_split=120; total time=   0.3s
# [CV 4/5] END ............max_depth=11, min_samples_split=120; total time=   0.3s
# [CV 5/5] END ............max_depth=11, min_samples_split=120; total time=   0.3s
# [CV 1/5] END .............max_depth=12, min_samples_split=30; total time=   0.3s
# [CV 2/5] END .............max_depth=12, min_samples_split=30; total time=   0.3s
# [CV 3/5] END .............max_depth=12, min_samples_split=30; total time=   0.3s
# [CV 4/5] END .............max_depth=12, min_samples_split=30; total time=   0.3s
# [CV 5/5] END .............max_depth=12, min_samples_split=30; total time=   0.3s
# [CV 1/5] END .............max_depth=12, min_samples_split=50; total time=   0.3s
# [CV 2/5] END .............max_depth=12, min_samples_split=50; total time=   0.3s
# [CV 3/5] END .............max_depth=12, min_samples_split=50; total time=   0.3s
# [CV 4/5] END .............max_depth=12, min_samples_split=50; total time=   0.3s
# [CV 5/5] END .............max_depth=12, min_samples_split=50; total time=   0.3s
# [CV 1/5] END ............max_depth=12, min_samples_split=100; total time=   0.3s
# [CV 2/5] END ............max_depth=12, min_samples_split=100; total time=   0.3s
# [CV 3/5] END ............max_depth=12, min_samples_split=100; total time=   0.3s
# [CV 4/5] END ............max_depth=12, min_samples_split=100; total time=   0.3s
# [CV 5/5] END ............max_depth=12, min_samples_split=100; total time=   0.3s
# [CV 1/5] END ............max_depth=12, min_samples_split=120; total time=   0.3s
# [CV 2/5] END ............max_depth=12, min_samples_split=120; total time=   0.3s
# [CV 3/5] END ............max_depth=12, min_samples_split=120; total time=   0.3s
# [CV 4/5] END ............max_depth=12, min_samples_split=120; total time=   0.3s
# [CV 5/5] END ............max_depth=12, min_samples_split=120; total time=   0.3s
# [CV 1/5] END .............max_depth=13, min_samples_split=30; total time=   0.3s
# [CV 2/5] END .............max_depth=13, min_samples_split=30; total time=   0.3s
# [CV 3/5] END .............max_depth=13, min_samples_split=30; total time=   0.3s
# [CV 4/5] END .............max_depth=13, min_samples_split=30; total time=   0.3s
# [CV 5/5] END .............max_depth=13, min_samples_split=30; total time=   0.3s
# [CV 1/5] END .............max_depth=13, min_samples_split=50; total time=   0.3s
# [CV 2/5] END .............max_depth=13, min_samples_split=50; total time=   0.3s
# [CV 3/5] END .............max_depth=13, min_samples_split=50; total time=   0.3s
# [CV 4/5] END .............max_depth=13, min_samples_split=50; total time=   0.3s
# [CV 5/5] END .............max_depth=13, min_samples_split=50; total time=   0.3s
# [CV 1/5] END ............max_depth=13, min_samples_split=100; total time=   0.3s
# [CV 2/5] END ............max_depth=13, min_samples_split=100; total time=   0.3s
# [CV 3/5] END ............max_depth=13, min_samples_split=100; total time=   0.3s
# [CV 4/5] END ............max_depth=13, min_samples_split=100; total time=   0.3s
# [CV 5/5] END ............max_depth=13, min_samples_split=100; total time=   0.3s
# [CV 1/5] END ............max_depth=13, min_samples_split=120; total time=   0.3s
# [CV 2/5] END ............max_depth=13, min_samples_split=120; total time=   0.3s
# [CV 3/5] END ............max_depth=13, min_samples_split=120; total time=   0.3s
# [CV 4/5] END ............max_depth=13, min_samples_split=120; total time=   0.3s
# [CV 5/5] END ............max_depth=13, min_samples_split=120; total time=   0.3s
# [CV 1/5] END .............max_depth=14, min_samples_split=30; total time=   0.4s
# [CV 2/5] END .............max_depth=14, min_samples_split=30; total time=   0.4s
# [CV 3/5] END .............max_depth=14, min_samples_split=30; total time=   0.4s
# [CV 4/5] END .............max_depth=14, min_samples_split=30; total time=   0.4s
# [CV 5/5] END .............max_depth=14, min_samples_split=30; total time=   0.3s
# [CV 1/5] END .............max_depth=14, min_samples_split=50; total time=   0.4s
# [CV 2/5] END .............max_depth=14, min_samples_split=50; total time=   0.4s
# [CV 3/5] END .............max_depth=14, min_samples_split=50; total time=   0.3s
# [CV 4/5] END .............max_depth=14, min_samples_split=50; total time=   0.3s
# [CV 5/5] END .............max_depth=14, min_samples_split=50; total time=   0.3s
# [CV 1/5] END ............max_depth=14, min_samples_split=100; total time=   0.3s
# [CV 2/5] END ............max_depth=14, min_samples_split=100; total time=   0.3s
# [CV 3/5] END ............max_depth=14, min_samples_split=100; total time=   0.3s
# [CV 4/5] END ............max_depth=14, min_samples_split=100; total time=   0.3s
# [CV 5/5] END ............max_depth=14, min_samples_split=100; total time=   0.3s
# [CV 1/5] END ............max_depth=14, min_samples_split=120; total time=   0.3s
# [CV 2/5] END ............max_depth=14, min_samples_split=120; total time=   0.3s
# [CV 3/5] END ............max_depth=14, min_samples_split=120; total time=   0.3s
# [CV 4/5] END ............max_depth=14, min_samples_split=120; total time=   0.3s
# [CV 5/5] END ............max_depth=14, min_samples_split=120; total time=   0.3s
# CPU times: user 31.3 s, sys: 141 ms, total: 31.5 s
# Wall time: 31.4 s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 11, 12, 13, 14],
#                          'min_samples_split': [30, 50, 100, 120]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
grid_search_results = pd.DataFrame(gs.cv_results_)
# we only keep some of the information
grid_search_results = grid_search_results[['param_max_depth', 'param_min_samples_split',
       'mean_test_score', 'mean_train_score']]

# %%
grid_search_results.sort_values("mean_test_score", ascending=False)
#the RMSE is similar to the one we used here, the MSE, a better MSE will still having better RMSE
# Out:
#    param_max_depth param_min_samples_split  mean_test_score  mean_train_score
# 16              14                      30        -0.014961         -0.009314
# 17              14                      50        -0.015413         -0.010940
# 12              13                      30        -0.015704         -0.010427
# 13              13                      50        -0.016110         -0.011825
# 8               12                      30        -0.016508         -0.011881
# 9               12                      50        -0.016987         -0.013026
# 18              14                     100        -0.017030         -0.013885
# 14              13                     100        -0.017497         -0.014458
# 19              14                     120        -0.017736         -0.014851
# 4               11                      30        -0.017763         -0.013771
# 15              13                     120        -0.018175         -0.015316
# 5               11                      50        -0.018186         -0.014654
# 10              12                     100        -0.018279         -0.015293
# 11              12                     120        -0.018698         -0.016069
# 6               11                     100        -0.019252         -0.016447
# 7               11                     120        -0.019570         -0.017117
# 0               10                      30        -0.019594         -0.016289
# 1               10                      50        -0.019893         -0.016937
# 2               10                     100        -0.020723         -0.018226
# 3               10                     120        -0.020927         -0.018747

# %%
best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=14, min_samples_split=30)

# %%
# its RMSE in the training
(mean_squared_error(best_tree.predict(X_train), y_train)) ** 0.5
# Out:
# 0.09624611653160611

# %%
# its RMSE in the test
(mean_squared_error(best_tree.predict(X_test), y_test)) ** 0.5
# Out:
# 0.11675406905360118

# %%
d_test2 = d_test.drop('price', axis = 1)

# %%
y_predict_2 = best_tree.predict(d_test2).round(3)

# %%
d_test2['price'] = y_predict_2
d_test2.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   0.32    5      6        5   60.5   58.0  4.43  4.49  2.70  6.108
# 1   1   1.24    4      6        5   62.9   60.0  6.80  6.74  4.26  8.354
# 2   2   1.66    4      5        5   62.0   59.0  7.55  7.60  4.70  9.524
# 3   3   0.75    4      5        1   60.6   56.0  5.94  5.90  3.59  7.900
# 4   4   1.50    1      2        1   64.8   55.0  7.26  7.15  4.67  8.946

# %%
d_up2 = d_test2.drop(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis = 1)

# %%
d_up2.to_csv('upload2.csv', index=False)

# %% [markdown]
# ###  Lets do a random forest

# %%
rf = RandomForestRegressor(n_estimators = 100, max_depth=10, max_features=9)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features=9)

# %%
y_pred_3 = rf.predict(X_test).round(3)

# %%
y_pred_3
# Out:
# array([6.605, 8.469, 6.628, ..., 7.676, 9.306, 7.892])

# %%
RMSE_rf = (mean_squared_error(y_test, y_pred_3)) ** 0.5
RMSE_rf
# Out:
# 0.12239815104227995

# %%
d_test3 = d_test.drop('price', axis = 1)

# %%
y_pred_4 = rf.predict(d_test3).round(3)

# %%
d_test3['price'] = y_pred_4
d_test3.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   0.32    5      6        5   60.5   58.0  4.43  4.49  2.70  6.165
# 1   1   1.24    4      6        5   62.9   60.0  6.80  6.74  4.26  8.520
# 2   2   1.66    4      5        5   62.0   59.0  7.55  7.60  4.70  9.391
# 3   3   0.75    4      5        1   60.6   56.0  5.94  5.90  3.59  7.860
# 4   4   1.50    1      2        1   64.8   55.0  7.26  7.15  4.67  8.902

# %%
# grid search with a random forest

# %%
gs = GridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid={
        "max_depth": [9, 10, 11, 12, 13, 14],
        "n_estimators": [50, 100, 150, 200],
        "max_features": [6, 7, 8, 9, 10], 
        "min_samples_split": [30, 50, 100, 120],
    },
    cv=5,
    verbose=3,
    scoring="neg_mean_squared_error",
    return_train_score=True
)

# %%
# the fit of this model is at the end of this notebook due to its HUGE scroll (sorry for the incovenience)

# %%
best_forest = gs.best_estimator_
best_forest
# Out:
# RandomForestRegressor(max_depth=14, max_features=9, min_samples_split=30,
#                       n_estimators=150)

# %%
# RMSE in the training
(mean_squared_error(best_forest.predict(X_train), y_train)) ** 0.5
# Out:
# 0.08885131073726121

# %%
# RMSE in the test
(mean_squared_error(best_forest.predict(X_test), y_test)) ** 0.5
# Out:
# 0.10172704216292572

# %%
y_pred5 = best_forest.predict(X_test).round(3)

# %%
RMSE_brf = (mean_squared_error(y_test, y_pred5)) ** 0.5
RMSE_brf
# Out:
# 0.10172960238292861

# %%
d_test4 = d_test.drop('price', axis = 1)

# %%
y_pred6 = best_forest.predict(d_test4).round(4)

# %%
d_test4['price'] = y_pred6
d_test4.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z   price
# 0   0   0.32    5      6        5   60.5   58.0  4.43  4.49  2.70  6.1435
# 1   1   1.24    4      6        5   62.9   60.0  6.80  6.74  4.26  8.5515
# 2   2   1.66    4      5        5   62.0   59.0  7.55  7.60  4.70  9.4283
# 3   3   0.75    4      5        1   60.6   56.0  5.94  5.90  3.59  7.8598
# 4   4   1.50    1      2        1   64.8   55.0  7.26  7.15  4.67  8.8881

# %%
d_up3 = d_test3.drop(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis = 1)
d_up3.to_csv('upload3.csv', index=False)

# %% [markdown]
# ### Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=400, max_depth=8, max_features=9)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=8, max_features=9, n_estimators=400)

# %%
y_pred10 = gb.predict(X_test).round(3)

# %%
RMSE_gb = (mean_squared_error(y_test, y_pred10)) ** 0.5
RMSE_gb
# Out:
# 0.0872115908270744

# %%
d_test5 = d_test.drop('price', axis = 1)
y_pred11 = gb.predict(d_test5).round(3)

# %%
d_test5['price'] = y_pred11
d_up4 = d_test3.drop(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis = 1)
d_up4.to_csv('upload4.csv', index=False)

# %%
# this ended up not working as well as it was supossed to
gs2 = GridSearchCV(
    estimator=GradientBoostingRegressor(),
    param_grid={
        "max_depth": [9, 10, 11],
        "n_estimators": [200, 250, 300],
        "max_features": [7, 8], 
        "min_samples_split": [30, 50, 100]
    },
    cv=5,
    scoring="neg_mean_squared_error",
    return_train_score=True
)

# %%
# lets do another gradient boosting model, based a little bit on what we know about depth, features...

# %%
gb2 = GradientBoostingRegressor(n_estimators=300, max_depth=12, max_features=7, min_samples_split = 30)
gb2.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=12, max_features=7, min_samples_split=30,
#                           n_estimators=300)

# %%
y_pred20 = gb2.predict(X_test).round(3)
RMSE_gb2 = (mean_squared_error(y_test, y_pred20)) ** 0.5
RMSE_gb2
# Out:
# 0.08904750023573149

# %%
d_test6 = d_test.drop('price', axis = 1)
y_pred21 = gb.predict(d_test6).round(3)
d_test6['price'] = y_pred21
d_up5 = d_test6.drop(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis = 1)
d_up5.to_csv('upload5.csv', index=False)

# %% [markdown]
# ## INFINITE SCROLL AHEAD.
# ### There is no more info appart from the scroll (you don't need to scroll all the way down)
# #### It is the fit of the Random Forest Grid Search

# %%
# %%time
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=50; total time=   5.1s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=50; total time=   5.2s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=50; total time=   5.1s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=50; total time=   5.0s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=50; total time=   5.2s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=100; total time=  10.4s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=100; total time=  10.3s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=100; total time=  10.2s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=100; total time=  10.3s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=100; total time=  10.3s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=150; total time=  15.4s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=150; total time=  15.6s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=150; total time=  15.3s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=150; total time=  15.2s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=150; total time=  15.2s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=200; total time=  20.5s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=200; total time=  20.4s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=200; total time=  18.7s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=200; total time=  19.2s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=30, n_estimators=200; total time=  19.7s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=50; total time=   5.0s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=50; total time=   5.2s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=50; total time=   4.9s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=50; total time=   4.9s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=50; total time=   5.0s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=100; total time=   9.8s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=100; total time=   9.9s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=100; total time=   9.7s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=100; total time=   9.9s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=100; total time=  10.0s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=150; total time=  14.7s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=150; total time=  14.7s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=150; total time=  14.3s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=150; total time=  14.3s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=150; total time=  14.6s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=200; total time=  18.9s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=200; total time=  19.7s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=200; total time=  19.7s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=200; total time=  19.6s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=50, n_estimators=200; total time=  19.8s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=50; total time=   4.9s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=50; total time=   4.9s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=50; total time=   4.8s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=50; total time=   4.9s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=50; total time=   4.7s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=100; total time=   9.6s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=100; total time=   9.6s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=100; total time=   9.7s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=100; total time=   9.7s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=100; total time=   9.7s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=150; total time=  14.8s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=150; total time=  15.0s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=150; total time=  14.6s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=150; total time=  14.7s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=150; total time=  14.6s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=200; total time=  19.3s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=200; total time=  19.0s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=200; total time=  19.4s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=200; total time=  19.3s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=100, n_estimators=200; total time=  19.4s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=50; total time=   4.8s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=50; total time=   4.9s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=50; total time=   4.9s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=50; total time=   4.8s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=50; total time=   4.9s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=100; total time=   9.6s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=100; total time=   9.8s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=100; total time=   9.8s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=100; total time=   9.8s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=100; total time=   9.8s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=150; total time=  14.0s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=150; total time=  13.8s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=150; total time=  14.2s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=150; total time=  13.0s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=150; total time=  14.6s
# [CV 1/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=200; total time=  19.2s
# [CV 2/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=200; total time=  18.7s
# [CV 3/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=200; total time=  18.8s
# [CV 4/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=200; total time=  18.8s
# [CV 5/5] END max_depth=9, max_features=6, min_samples_split=120, n_estimators=200; total time=  18.7s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=50; total time=   5.6s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=50; total time=   5.7s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=50; total time=   5.8s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=50; total time=   5.5s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=50; total time=   3.8s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=100; total time=   3.4s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=100; total time=   3.3s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=100; total time=   3.3s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=100; total time=   3.6s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=100; total time=   3.4s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=150; total time=   5.8s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=150; total time=   5.3s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=150; total time=   5.1s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=150; total time=   5.2s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=150; total time=   4.7s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=200; total time=   6.6s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=200; total time=   6.6s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=200; total time=   6.4s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=200; total time=   6.6s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=30, n_estimators=200; total time=   6.6s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=50; total time=   1.6s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=50; total time=   1.6s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=50; total time=   1.7s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=50; total time=   1.7s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=50; total time=   1.6s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=100; total time=   3.1s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=100; total time=   3.4s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=100; total time=   3.1s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=100; total time=   3.2s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=100; total time=   3.4s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=150; total time=   4.9s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=150; total time=   5.1s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=150; total time=   5.1s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=150; total time=   5.2s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=150; total time=   5.4s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=200; total time=   7.1s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=200; total time=   7.1s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=200; total time=   7.0s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=200; total time=   6.9s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=50, n_estimators=200; total time=   6.8s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=50; total time=   1.7s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=50; total time=   1.7s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=100; total time=   3.4s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=100; total time=   3.3s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=100; total time=   3.3s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=100; total time=   3.5s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=100; total time=   3.3s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=150; total time=   5.2s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=150; total time=   4.9s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=150; total time=   4.7s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=150; total time=   5.1s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=150; total time=   5.3s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=200; total time=   6.9s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=200; total time=   6.7s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=200; total time=   6.4s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=200; total time=   6.5s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=100, n_estimators=200; total time=   6.6s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=50; total time=   1.5s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=50; total time=   1.6s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=50; total time=   1.7s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=50; total time=   1.6s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=50; total time=   1.4s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=100; total time=   3.0s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=100; total time=   3.4s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=100; total time=   3.0s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=100; total time=   3.1s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=100; total time=   3.3s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=150; total time=   4.7s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=150; total time=   4.8s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=150; total time=   4.6s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=150; total time=   5.1s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=150; total time=   5.4s
# [CV 1/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=200; total time=   6.6s
# [CV 2/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=200; total time=   6.6s
# [CV 3/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=200; total time=   6.7s
# [CV 4/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=200; total time=   6.6s
# [CV 5/5] END max_depth=9, max_features=7, min_samples_split=120, n_estimators=200; total time=   6.3s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=50; total time=   2.0s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=50; total time=   1.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=50; total time=   1.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=50; total time=   1.9s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=50; total time=   2.0s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=100; total time=   3.6s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=100; total time=   3.7s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=100; total time=   3.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=100; total time=   3.8s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=100; total time=   3.9s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=150; total time=   5.5s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=150; total time=   5.7s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=150; total time=   5.7s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=150; total time=   5.5s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=150; total time=   5.9s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=200; total time=   7.6s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=200; total time=   7.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=200; total time=   7.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=200; total time=   9.8s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=30, n_estimators=200; total time=   8.7s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=50; total time=   2.0s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=50; total time=   2.0s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=50; total time=   2.0s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=50; total time=   1.9s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=50; total time=   1.9s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=100; total time=   3.8s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=100; total time=   3.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=100; total time=   3.6s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=100; total time=   3.9s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=100; total time=   3.6s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=150; total time=   5.6s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=150; total time=   5.6s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=150; total time=   5.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=150; total time=   6.0s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=150; total time=   5.7s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=200; total time=   7.8s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=200; total time=   7.6s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=200; total time=   7.6s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=200; total time=   7.5s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=50, n_estimators=200; total time=   7.5s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=50; total time=   2.0s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=50; total time=   1.9s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=50; total time=   2.0s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=50; total time=   2.5s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=50; total time=   2.0s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=100; total time=   3.8s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=100; total time=   3.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=100; total time=   4.0s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=100; total time=   3.5s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=100; total time=   3.8s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=150; total time=   5.7s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=150; total time=   5.5s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=150; total time=   5.5s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=150; total time=   5.4s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=150; total time=   5.5s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=200; total time=   7.8s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=200; total time=   7.5s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=200; total time=   7.5s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=200; total time=   7.7s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=100, n_estimators=200; total time=   7.7s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=50; total time=   1.9s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=50; total time=   1.9s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=50; total time=   1.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=50; total time=   2.0s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=50; total time=   1.9s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=100; total time=   3.9s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=100; total time=   3.6s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=100; total time=   3.9s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=100; total time=   4.1s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=100; total time=   4.0s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=150; total time=   5.8s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=150; total time=   5.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=150; total time=   5.8s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=150; total time=   5.6s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=150; total time=   5.7s
# [CV 1/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=200; total time=   7.4s
# [CV 2/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=200; total time=   7.8s
# [CV 3/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=200; total time=   7.6s
# [CV 4/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=200; total time=   7.6s
# [CV 5/5] END max_depth=9, max_features=8, min_samples_split=120, n_estimators=200; total time=   7.4s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=50; total time=   2.2s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=50; total time=   2.2s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=50; total time=   2.2s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=50; total time=   2.1s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=50; total time=   2.3s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=100; total time=   4.1s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=100; total time=   4.2s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=100; total time=   4.5s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=100; total time=   4.4s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=100; total time=   4.2s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=150; total time=   6.7s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=150; total time=   6.4s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=150; total time=   6.5s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=150; total time=   6.6s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=150; total time=   6.9s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=200; total time=   9.0s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=200; total time=   9.0s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=200; total time=   8.9s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=200; total time=   8.9s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=30, n_estimators=200; total time=   8.9s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=50; total time=   2.1s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=50; total time=   2.2s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=50; total time=   2.2s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=50; total time=   2.2s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=50; total time=   2.2s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=100; total time=   4.4s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=100; total time=   4.3s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=100; total time=   4.5s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=100; total time=   4.3s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=100; total time=   4.3s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=150; total time=   6.5s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=150; total time=   7.0s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=150; total time=   7.0s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=150; total time=   7.7s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=150; total time=   6.9s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=200; total time=   9.0s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=200; total time=   9.7s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=200; total time=   9.6s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=200; total time=   9.1s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=50, n_estimators=200; total time=   8.7s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=50; total time=   2.1s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=50; total time=   2.1s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=50; total time=   2.2s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=50; total time=   2.2s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=50; total time=   2.1s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=100; total time=   4.2s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=100; total time=   4.6s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=100; total time=   4.8s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=100; total time=   5.2s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=100; total time=   4.5s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=150; total time=   6.8s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=150; total time=   6.7s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=150; total time=   6.7s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=150; total time=   6.6s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=150; total time=   6.4s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=200; total time=   8.7s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=200; total time=   8.7s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=200; total time=   8.3s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=200; total time=   8.5s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=100, n_estimators=200; total time=   8.8s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=50; total time=   2.3s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=50; total time=   2.1s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=50; total time=   2.0s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=50; total time=   2.4s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=50; total time=   2.2s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=100; total time=   4.4s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=100; total time=   4.3s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=100; total time=   4.3s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=100; total time=   4.4s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=100; total time=   4.3s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=150; total time=   6.4s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=150; total time=   6.3s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=150; total time=   6.1s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=150; total time=   6.3s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=150; total time=   6.3s
# [CV 1/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=200; total time=   8.4s
# [CV 2/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=200; total time=   8.5s
# [CV 3/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=200; total time=   8.2s
# [CV 4/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=200; total time=   8.4s
# [CV 5/5] END max_depth=9, max_features=9, min_samples_split=120, n_estimators=200; total time=   8.3s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=50; total time=   2.7s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=50; total time=   2.7s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=50; total time=   2.6s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=50; total time=   2.5s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=50; total time=   2.4s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=100; total time=   4.9s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=100; total time=   4.7s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=100; total time=   5.0s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=100; total time=   4.8s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=100; total time=   5.0s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=150; total time=   7.3s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=150; total time=   7.0s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=150; total time=   7.0s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=150; total time=   7.3s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=150; total time=   7.1s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=200; total time=   9.3s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=200; total time=   9.7s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=200; total time=   9.8s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=200; total time=   9.4s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=30, n_estimators=200; total time=   9.8s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=50; total time=   2.5s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=50; total time=   2.4s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=50; total time=   2.4s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=50; total time=   2.4s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=50; total time=   2.5s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=100; total time=   4.8s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=100; total time=   5.0s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=100; total time=   5.5s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=100; total time=   5.1s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=100; total time=   5.2s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=150; total time=   7.4s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=150; total time=   7.3s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=150; total time=   7.3s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=150; total time=   7.1s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=150; total time=   7.4s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=200; total time=   9.7s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=200; total time=   9.8s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=200; total time=   9.8s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=200; total time=   9.6s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=50, n_estimators=200; total time=   9.8s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=50; total time=   2.5s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=50; total time=   2.3s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=50; total time=   2.3s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=50; total time=   2.4s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=50; total time=   2.3s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=100; total time=   4.6s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=100; total time=   4.7s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=100; total time=   4.7s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=100; total time=   4.8s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=100; total time=   4.9s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=150; total time=   7.1s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=150; total time=   7.2s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=150; total time=   7.2s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=150; total time=   7.2s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=150; total time=   7.2s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=200; total time=   9.3s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=200; total time=   9.4s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=200; total time=   9.3s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=200; total time=   9.4s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=100, n_estimators=200; total time=   9.6s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=50; total time=   2.3s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=50; total time=   2.4s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=50; total time=   2.3s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=50; total time=   2.3s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=50; total time=   2.4s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=100; total time=   4.7s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=100; total time=   4.6s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=100; total time=   4.6s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=100; total time=   4.9s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=100; total time=   4.6s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=150; total time=   7.1s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=150; total time=   7.3s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=150; total time=   7.0s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=150; total time=   6.9s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=150; total time=   7.0s
# [CV 1/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=200; total time=   9.5s
# [CV 2/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=200; total time=   9.6s
# [CV 3/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=200; total time=   9.1s
# [CV 4/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=200; total time=   9.4s
# [CV 5/5] END max_depth=9, max_features=10, min_samples_split=120, n_estimators=200; total time=   9.4s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=50; total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=50; total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=50; total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=50; total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=50; total time=   1.8s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=100; total time=   3.4s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=100; total time=   3.1s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=100; total time=   3.2s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=100; total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=100; total time=   3.4s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=150; total time=   5.0s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=150; total time=   5.1s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=150; total time=   4.9s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=150; total time=   5.0s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=150; total time=   4.9s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=200; total time=   6.7s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=200; total time=   6.7s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=200; total time=   6.9s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=200; total time=   7.4s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=30, n_estimators=200; total time=   7.1s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=50; total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=50; total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=50; total time=   1.9s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=50; total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=50; total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=100; total time=   3.4s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=100; total time=   3.5s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=100; total time=   3.8s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=100; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=100; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=150; total time=   5.4s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=150; total time=   5.3s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=150; total time=   5.4s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=150; total time=   5.4s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=150; total time=   5.7s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=200; total time=   7.1s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=200; total time=   7.0s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=200; total time=   6.6s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=200; total time=   6.8s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=50, n_estimators=200; total time=   6.7s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=50; total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=50; total time=   2.0s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=100; total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=100; total time=   3.3s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=100; total time=   3.4s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=100; total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=100; total time=   3.3s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=150; total time=   4.8s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=150; total time=   4.9s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=150; total time=   4.9s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=150; total time=   5.3s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=150; total time=   5.0s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=200; total time=   6.8s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=200; total time=   6.9s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=200; total time=   6.7s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=200; total time=   6.4s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=100, n_estimators=200; total time=   6.4s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=50; total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=50; total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=50; total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=50; total time=   1.4s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=50; total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=100; total time=   3.1s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=100; total time=   3.1s
# [CV 3/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=100; total time=   2.8s
# [CV 4/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=100; total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=100; total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=150; total time=   4.6s
# [CV 2/5] END max_depth=10, max_features=6, min_samples_split=120, n_estimators=150; total time=   4.7s
# ...
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=150; total time=  29.6s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=150; total time=  28.4s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=150; total time=  29.5s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=150; total time=  29.7s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=150; total time=  29.5s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=200; total time=  37.9s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=200; total time=  38.3s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=200; total time=  39.5s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=200; total time=  39.3s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=30, n_estimators=200; total time=  40.0s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=50; total time=   9.5s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=50; total time=   9.4s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=50; total time=   9.3s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=50; total time=   9.4s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=50; total time=   9.4s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=100; total time=  18.8s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=100; total time=  18.7s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=100; total time=  18.8s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=100; total time=  18.6s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=100; total time=  18.7s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=150; total time=  27.9s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=150; total time=  28.1s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=150; total time=  27.8s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=150; total time=  27.0s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=150; total time=  28.3s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=200; total time=  37.4s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=200; total time=  37.8s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=200; total time=  37.7s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=200; total time=  39.1s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=50, n_estimators=200; total time=  39.0s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=50; total time=   8.6s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=50; total time=   8.6s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=50; total time=   8.6s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=50; total time=   8.7s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=50; total time=   8.6s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=100; total time=  16.8s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=100; total time=  17.0s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=100; total time=  17.2s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=100; total time=  17.2s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=100; total time=  17.2s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=150; total time=  25.5s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=150; total time=  25.6s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=150; total time=  25.3s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=150; total time=  25.6s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=150; total time=  25.5s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=200; total time=  33.9s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=200; total time=  34.2s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=200; total time=  34.1s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=200; total time=  34.0s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=100, n_estimators=200; total time=  34.3s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=50; total time=   8.3s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=50; total time=   8.3s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=50; total time=   8.3s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=50; total time=   8.3s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=50; total time=   8.3s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=100; total time=  16.5s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=100; total time=  16.5s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=100; total time=  16.9s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=100; total time=  16.7s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=100; total time=  16.7s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=150; total time=  24.8s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=150; total time=  24.6s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=150; total time=  24.7s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=150; total time=  24.9s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=150; total time=  25.2s
# [CV 1/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=200; total time=  32.8s
# [CV 2/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=200; total time=  33.0s
# [CV 3/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=200; total time=  33.1s
# [CV 4/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=200; total time=  33.4s
# [CV 5/5] END max_depth=14, max_features=9, min_samples_split=120, n_estimators=200; total time=  33.3s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=50; total time=  10.8s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=50; total time=  10.9s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=50; total time=  11.0s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=50; total time=  11.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=50; total time=  10.9s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=100; total time=  21.6s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=100; total time=  21.9s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=100; total time=  21.9s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=100; total time=  21.8s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=100; total time=  22.0s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=150; total time=  32.6s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=150; total time=  33.0s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=150; total time=  32.6s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=150; total time=  33.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=150; total time=  33.2s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=200; total time=  43.5s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=200; total time=  43.5s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=200; total time=  43.2s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=200; total time=  43.6s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=30, n_estimators=200; total time=  44.1s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=50; total time=   8.4s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=50; total time=   6.7s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=50; total time=   6.7s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=50; total time=   6.7s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=50; total time=   6.7s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=100; total time=  13.3s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=100; total time=  13.4s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=100; total time=  13.2s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=100; total time=  13.3s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=100; total time=  13.3s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=150; total time=  19.9s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=150; total time=  20.0s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=150; total time=  19.7s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=150; total time=  19.8s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=150; total time=  19.8s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=200; total time=  26.3s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=200; total time=  26.5s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=200; total time=  26.3s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=200; total time=  26.5s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=50, n_estimators=200; total time=  26.5s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=50; total time=   6.0s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=50; total time=   6.0s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=50; total time=   6.0s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=50; total time=   6.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=50; total time=   6.1s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=100; total time=  12.0s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=100; total time=  12.1s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=100; total time=  12.0s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=100; total time=  12.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=100; total time=  12.2s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=150; total time=  18.0s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=150; total time=  18.1s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=150; total time=  18.0s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=150; total time=  18.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=150; total time=  18.2s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=200; total time=  24.3s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=200; total time=  24.0s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=200; total time=  24.0s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=200; total time=  24.0s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=100, n_estimators=200; total time=  24.1s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=50; total time=   5.8s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=50; total time=   5.9s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=50; total time=   5.8s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=50; total time=   5.9s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=50; total time=   5.9s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=100; total time=  11.7s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=100; total time=  11.7s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=100; total time=  11.7s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=100; total time=  11.7s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=100; total time=  11.7s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=150; total time=  17.5s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=150; total time=  17.5s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=150; total time=  17.5s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=150; total time=  17.5s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=150; total time=  17.7s
# [CV 1/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=200; total time=  23.4s
# [CV 2/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=200; total time=  23.4s
# [CV 3/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=200; total time=  23.2s
# [CV 4/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=200; total time=  23.4s
# [CV 5/5] END max_depth=14, max_features=10, min_samples_split=120, n_estimators=200; total time=  23.5s
# CPU times: user 5h 13min 13s, sys: 21.4 s, total: 5h 13min 34s
# Wall time: 5h 14min 15s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [9, 10, 11, 12, 13, 14],
#                          'max_features': [6, 7, 8, 9, 10],
#                          'min_samples_split': [30, 50, 100, 120],
#                          'n_estimators': [50, 100, 150, 200]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)
